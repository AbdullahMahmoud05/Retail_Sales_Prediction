# %%
#Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,r2_score,mean_squared_error

# %%
df = pd.read_csv('retail_store_sales_cleaned.csv')

# %%
df.head()
# Out:
#    Category  Item  Price Per Unit  Quantity  Total Spent  Payment Method  \
# 0         3    99            35.0        10        350.0               0
# 1         2   170            12.5         6         75.0               2
# 2         6   158             9.5         7         66.5               1
# 3         0   184            15.5         5         77.5               1
# 4         4    68            30.5        10        305.0               2
#
#    Location Transaction Date  Discount Applied  Year  Month  Day  Weekday
# 0         1       2022-01-01                 1  2022      1    1        5
# 1         0       2022-01-01                 1  2022      1    1        5
# 2         1       2022-01-01                 0  2022      1    1        5
# 3         1       2022-01-01                 1  2022      1    1        5
# 4         0       2022-01-01                 0  2022      1    1        5

# %%
df['Year'].unique()
# Out:
# array([2022, 2023, 2024, 2025])

# %%
#features 2D
x = df.drop(['Item','Total Spent','Transaction Date'], axis=1)

# %%
#targrt 2D
y=np.array(df['Total Spent']).reshape(-1,1)

# %%
print(x.shape,y.shape)
# Out:
# (11971, 10) (11971, 1)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=17)

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8966944103505515

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 940.7206461276984

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 22.974116521069398
